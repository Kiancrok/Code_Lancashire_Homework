# %% [markdown]
# <h1>Tackling an open problem</h1>
#
# For this homework the idea is to hone our skills on exploring and plotting a dataset. You can either work with the Pokemon dataset that was given or download your own. If you opt to download your own I recommend you use one of the datasets available on kaggle,
#
# https://www.kaggle.com/datasets
#
# As they tend to be found in a clean format and are generally free to use.
#
# Largely, the main objective is learning how to search the internet for new implementations you want to use on your code helping you develop your self-confidence.
#
# There's no right or wrong, pick a dataset you enjoy and try to have some fun.
# If you need, use the notebook from the previous session as a guideline.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
f1_df = pd.read_csv('archive\drivers.csv', sep=',')

# %%
f1_df.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
f1_df [['driverRef','number']]
# Out:
#            driverRef number
# 0           hamilton     44
# 1           heidfeld     \N
# 2            rosberg      6
# 3             alonso     14
# 4         kovalainen     \N
# ..               ...    ...
# 852  mick_schumacher     47
# 853             zhou     24
# 854         de_vries     21
# 855          piastri     81
# 856         sargeant      2
#
# [857 rows x 2 columns]

# %%
f1_df[(f1_df['nationality'] == 'British')]
# Out:
#      driverId      driverRef number code forename    surname         dob  \
# 0           1       hamilton     44  HAM    Lewis   Hamilton  1985-01-07
# 13         14      coulthard     \N  COU    David  Coulthard  1971-03-27
# 17         18         button     22  BUT   Jenson     Button  1980-01-19
# 18         19       davidson     \N  DAV  Anthony   Davidson  1979-04-18
# 50         51         wilson     \N   \N   Justin     Wilson  1978-07-31
# ..        ...            ...    ...  ...      ...        ...         ...
# 828       829        stevens     28  STE     Will    Stevens  1991-06-28
# 834       835  jolyon_palmer     30  PAL   Jolyon     Palmer  1991-01-20
# 844       846         norris      4  NOR    Lando     Norris  1999-11-13
# 845       847        russell     63  RUS   George    Russell  1998-02-15
# 849       851         aitken     89  AIT     Jack     Aitken  1995-09-23
#
#     nationality                                                url
# ...

# %%
len(f1_df[(f1_df['nationality'] == 'British')])
# Out:
# 165

# %%
f1_df.sort_values(by=['number'])[0:10]
# Out:
#      driverId      driverRef number code  forename    surname         dob  \
# 154       155      kobayashi     10  KOB     Kamui  Kobayashi  1986-09-13
# 452       842          gasly     10  GAS    Pierre      Gasly  1996-02-07
# 814       815          perez     11  PER    Sergio      Pérez  1990-01-26
# 830       831           nasr     12  NAS    Felipe       Nasr  1992-08-21
# 812       813      maldonado     13  MAL    Pastor  Maldonado  1985-03-09
# 3           4         alonso     14  ALO  Fernando     Alonso  1981-07-29
# 842       844        leclerc     16  LEC   Charles    Leclerc  1997-10-16
# 823       824  jules_bianchi     17  BIA     Jules    Bianchi  1989-08-03
# 839       840         stroll     18  STR     Lance     Stroll  1998-10-29
# 12         13          massa     19  MAS    Felipe      Massa  1981-04-25
#
#     nationality                                             url
# 154    Japanese    http://en.wikipedia.org/wiki/Kamui_Kobayashi
# ...

# %%
f1_df.hist()
# Out:
# array([[<Axes: title={'center': 'driverId'}>]], dtype=object)

# %%
f1d_df = pd.read_csv('archive\driver_standings.csv', sep=',')

# %%
f1d_df
# Out:
#        driverStandingsId  raceId  driverId  points  position positionText  \
# 0                      1      18         1    10.0         1            1
# 1                      2      18         2     8.0         2            2
# 2                      3      18         3     6.0         3            3
# 3                      4      18         4     5.0         4            4
# 4                      5      18         5     4.0         5            5
# ...                  ...     ...       ...     ...       ...          ...
# 34119              72183    1110       846    69.0         8            8
# 34120              72184    1110       839    35.0        10           10
# 34121              72185    1110       844    99.0         5            5
# 34122              72186    1110       857    34.0        11           11
# 34123              72187    1110       817     0.0        21           21
#
#        wins
# 0         1
# 1         0
# 2         0
# 3         0
# ...

# %%
f1d_df.tail(21)
# Out:
#        driverStandingsId  raceId  driverId  points  position positionText  \
# 34103              72167    1110       830   314.0         1            1
# 34104              72168    1110       815   189.0         2            2
# 34105              72169    1110         4   149.0         3            3
# 34106              72170    1110       832    92.0         7            7
# 34107              72171    1110         1   148.0         4            4
# 34108              72172    1110       840    47.0         9            9
# 34109              72173    1110       847    99.0         6            6
# 34110              72174    1110       822     5.0        15           15
# 34111              72175    1110       842    22.0        12           12
# 34112              72176    1110       848    11.0        13           13
# 34113              72177    1110       852     3.0        17           17
# 34114              72178    1110       858     0.0        19           19
# ...

# %%
f1d_df['points'].describe()
# Out:
# count    34124.000000
# mean        13.489987
# std         35.599709
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%         10.000000
# max        454.000000
# Name: points, dtype: float64

# %%
f1d_df.tail(21).hist('points')
# Out:
# array([[<Axes: title={'center': 'points'}>]], dtype=object)

# %%
f1d_df.tail(21)['points'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
f1d_df.tail(21).plot.scatter(x='driverid',y='points',s=1, c='black')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'driverid'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 1
# ...

# %%
f1_df = f1_df.drop(['driverid'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 f1_df = f1_df.drop(['driverid'], axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
#I thought the errors were because both sets of data have a driverId but looking at it for a minute i realised it was that the I
#in driverId was capital

# %%
f1d_df.tail(21).plot.scatter(x='driverId',y='points',s=1, c='black')
# Out:
# <Axes: xlabel='driverId', ylabel='points'>

# %%
f1d_df.tail(21)
# Out:
#        driverStandingsId  raceId  driverId  points  position positionText  \
# 34103              72167    1110       830   314.0         1            1
# 34104              72168    1110       815   189.0         2            2
# 34105              72169    1110         4   149.0         3            3
# 34106              72170    1110       832    92.0         7            7
# 34107              72171    1110         1   148.0         4            4
# 34108              72172    1110       840    47.0         9            9
# 34109              72173    1110       847    99.0         6            6
# 34110              72174    1110       822     5.0        15           15
# 34111              72175    1110       842    22.0        12           12
# 34112              72176    1110       848    11.0        13           13
# 34113              72177    1110       852     3.0        17           17
# 34114              72178    1110       858     0.0        19           19
# ...

# %%
fig,axes = plt.subplots(nrows=1,ncols=3,figsize=(12,6))
f1d_df.tail(21)['points'].plot.hist(ax=axes[0], bins=50, alpha=0.5, color='red')
axes[0].set_title('points')

f1d_df.tail(21)['driverId'].plot.hist(ax=axes[1], bins=50, alpha=0.5, color='green')
axes[1].set_title('driverid')

f1d_df.tail(21)['wins'].plot.hist(ax=axes[2], bins=50, alpha=0.5, color='blue')
axes[2].set_title('wins')
# Out:
# Text(0.5, 1.0, 'wins')
